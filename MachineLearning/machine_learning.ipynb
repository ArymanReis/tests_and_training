# %%
# %pip install pandas numpy matplotlib scikit-learn scipy seaborn statsmodels jupyterlab
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----------------- ---------------------- 5.0/11.1 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 30.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 25.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    ------ --------------------------------- 7.1/41.0 MB 35.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 16.5/41.0 MB 41.4 MB/s eta 0:00:01
#    ------------------------ --------------- 25.2/41.0 MB 40.8 MB/s eta 0:00:01
#    ------------------------------ --------- 31.5/41.0 MB 39.3 MB/s eta 0:00:01
#    -------------------------------- ------- 33.3/41.0 MB 32.2 MB/s eta 0:00:01
# ...
